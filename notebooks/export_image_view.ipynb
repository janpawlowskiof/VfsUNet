# %%
import cv2
import matplotlib.pyplot as plt

paths = [
    "images_for_comparisons/gta_v_39/1542_blocky.png",
    "images_for_comparisons/gta_v_39/1542_deblocked.png",
]

images = [cv2.imread(path) for path in paths]

start_x, end_x = 125, 425
start_y, end_y = 350, 630

images = [
    image[start_y:end_y, start_x:end_x, :]
    for image in images
]

plt.figure(figsize=(12, 12))
plt.imshow(cv2.cvtColor(images[0], cv2.COLOR_BGR2RGB))

for index, image in enumerate(images):
    cv2.imwrite(f"images/blocks/{index}.png", image)

# %%
for index, image in enumerate(images):
    cv2.imwrite(f"tf2_cutouts_2/tf2_soldier{index}.png", image)

# %%
paths = [
    "images/hevc_vs_avc/avc026.png",
    "images/hevc_vs_avc/hevc026.png",
]

images = [cv2.imread(path) for path in paths]

start_x, end_x = 500, 750
start_y, end_y = 350, 550

images = [
    image[start_y:end_y, start_x:end_x, :]
    for image in images
]

plt.figure(figsize=(12, 12))
plt.imshow(cv2.cvtColor(images[0], cv2.COLOR_BGR2RGB))

for index, image in enumerate(images):
    cv2.imwrite(f"images/hevc_vs_avc/{index}.png", image)

# %%
#
paths = [
    "/home/sportv14/streaming_nn/run/GrandTheftAutoV2021.11.07-11.29.04.11_images/1499_deblocked.png",
    "/home/sportv14/streaming_nn/run/GrandTheftAutoV2021.11.07-11.29.04.11_images/1499_pred.png",
    "/home/sportv14/streaming_nn/run/GrandTheftAutoV2021.11.07-11.29.04.11_images/1499_raw.png",
]

images = [cv2.imread(path) for path in paths]

start_x, end_x = 790, 880
start_y, end_y = 80, 260

images = [
    image[start_y:end_y, start_x:end_x, :]
    for image in images
]

plt.figure(figsize=(12, 12))
plt.imshow(cv2.cvtColor(images[0], cv2.COLOR_BGR2RGB))

for index, image in enumerate(images):
    cv2.imwrite(f"images/comparisons/gta_v_1499/head_{index}.png", image)

# %%
from pathlib import Path

paths = [
    "/home/sportv14/streaming_nn/run/GrandTheftAutoV2021.11.07-11.29.04.11_images/1488_deblocked.png",
    "/home/sportv14/streaming_nn/run/GrandTheftAutoV2021.11.07-11.29.04.11_images/1488_pred.png",
    "/home/sportv14/streaming_nn/run/GrandTheftAutoV2021.11.07-11.29.04.11_images/1488_raw.png",
    "/home/sportv14/streaming_nn/run/GrandTheftAutoV2021.11.07-11.29.04.11_images/1488_blocky.png",
]

images = [cv2.imread(path) for path in paths]

start_x, end_x = 380, 550
start_y, end_y = 200, 380

images = [
    image[start_y:end_y, start_x:end_x, :]
    for image in images
]

plt.figure(figsize=(12, 12))
plt.imshow(cv2.cvtColor(images[0], cv2.COLOR_BGR2RGB))

for path, image in zip(paths, images):
    path = Path(path)
    cv2.imwrite(f"images/comparisons/gta_v_1499/tracy_{path.stem}.png", image)

# %%
paths = [
    "/home/sportv14/streaming_nn/run/KatanaZero2021.10.24-19.35.22.02_qp=37_images/6316_blocky.png",
    "/home/sportv14/streaming_nn/run/KatanaZero2021.10.24-19.35.22.02_qp=37_images/6316_raw.png",
]

images = [cv2.imread(path) for path in paths]

start_x, end_x = 430, 800
start_y, end_y = 310, 480

images = [
    image[start_y:end_y, start_x:end_x, :]
    for image in images
]

plt.figure(figsize=(16, 16))
plt.imshow(cv2.cvtColor(images[0], cv2.COLOR_BGR2RGB))
plt.show()

for index, image in enumerate(images):
    cv2.imwrite(f"images/katana_details/{index}.png", image)
